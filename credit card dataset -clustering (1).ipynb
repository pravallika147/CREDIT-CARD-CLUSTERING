# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\remel\\Downloads\\CC GENERAL.csv")

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
mean=df['CREDIT_LIMIT'].mean()
df['CREDIT_LIMIT']=df['CREDIT_LIMIT'].fillna(mean)

# %%
df['MINIMUM_PAYMENTS']=df['MINIMUM_PAYMENTS'].fillna(mean)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.drop('CUST_ID',axis=1,inplace=True)

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
df.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
mode=df['BALANCE_FREQUENCY'].mode()[0]
df['BALANCE_FREQUENCY']=df['BALANCE_FREQUENCY'].fillna(mode)

# %%
df.describe().T
# Out:
#                                    count         mean          std        min  \
# BALANCE                           8950.0  1564.474828  2081.531879   0.000000
# BALANCE_FREQUENCY                 8950.0     0.877271     0.236904   0.000000
# PURCHASES                         8950.0  1003.204834  2136.634782   0.000000
# ONEOFF_PURCHASES                  8950.0   592.437371  1659.887917   0.000000
# INSTALLMENTS_PURCHASES            8950.0   411.067645   904.338115   0.000000
# CASH_ADVANCE                      8950.0   978.871112  2097.163877   0.000000
# PURCHASES_FREQUENCY               8950.0     0.490351     0.401371   0.000000
# ONEOFF_PURCHASES_FREQUENCY        8950.0     0.202458     0.298336   0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  8950.0     0.364437     0.397448   0.000000
# CASH_ADVANCE_FREQUENCY            8950.0     0.135144     0.200121   0.000000
# CASH_ADVANCE_TRX                  8950.0     3.248827     6.824647   0.000000
# ...

# %%
for i in df:
    sns.boxplot(df[i])
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
sc=scaler.fit_transform(df)

# %%
sc_df=pd.DataFrame(sc,columns=df.columns)
sc_df.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0 -0.731989          -0.249434  -0.424900         -0.356934
# 1  0.786961           0.134325  -0.469552         -0.356934
# 2  0.447135           0.518084  -0.107668          0.108889
# 3  0.049099          -1.016953   0.232058          0.546189
# 4 -0.358775           0.518084  -0.462063         -0.347294
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0               -0.349079     -0.466786            -0.806490
# 1               -0.454576      2.605605            -1.221758
# 2               -0.454576     -0.466786             1.269843
# 3               -0.454576     -0.368653            -1.014125
# 4               -0.454576     -0.466786            -1.014125
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   -0.678661                         -0.707313
# 1                   -0.678661                         -0.916995
# ...

# %%
# import variance
# calculated variance for each column
variances = df.var()
# sort variance in desecending order and select the to 2
top_col=variances.sort_values(ascending=False).head(2)
top_col
# Out:
# CREDIT_LIMIT    1.323950e+07
# PAYMENTS        8.381394e+06
# dtype: float64

# %% [markdown]
# * We do the Elbow Method in Clustering

# %%
X=df[['PAYMENTS','CREDIT_LIMIT']].values

# %%
from sklearn.cluster import KMeans
wcss =[]
for i in range(1,8):
    kmean=KMeans(n_clusters=i , init='k-means++',random_state=30)
    kmean.fit(X)
    wcss.append(kmean.inertia_)

# %%
wcss
# Out:
# [193485384310.1394,
#  103105820031.14664,
#  69158614466.54112,
#  51355245820.43479,
#  38894135705.14193,
#  33718555305.86826,
#  28159434295.644646]

# %%
# plt.plot(range(1,8),wcss
sns.set()
plt.plot(range(1,8), wcss)
plt.title('The Elbow Point Graph')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=2, init='k-means++', random_state=0)

# return a label for each data point based on their cluster
Y = kmeans.fit_predict(X)

print(Y)
# Out:
# [1 0 0 ... 1 1 1]

# %%
from sklearn.metrics import silhouette_score
silhouette_score(X,Y)
# Out:
# 0.5755097606252411

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
pca.fit_transform(X)
# Out:
# array([[-3786.77718869,   465.29893068],
#        [ 3363.92413643,   760.3753183 ],
#        [ 2018.41784172, -2488.73780601],
#        ...,
#        [-3848.25775772,   361.6266775 ],
#        [-4292.9712446 ,   591.96295312],
#        [-3685.46750606,   244.03782419]])

# %%
from sklearn.metrics import silhouette_score
silhouette_score(X,Y)
# Out:
# 0.5755097606252411

# %%
# plotting all the clusters and their Centroids

plt.figure(figsize=(8,8))
plt.scatter(X[Y==0,0], X[Y==0,1], s=50, c='green', label='Cluster 1')
plt.scatter(X[Y==1,0], X[Y==1,1], s=50, c='red', label='Cluster 2')
plt.scatter(X[Y==2,0], X[Y==2,1], s=50, c='yellow', label='Cluster 3')
plt.scatter(X[Y==3,0], X[Y==3,1], s=50, c='violet', label='Cluster 4')
plt.scatter(X[Y==4,0], X[Y==4,1], s=50, c='blue', label='Cluster 5')

# plot the centroids
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=100, c='cyan', label='Centroids')

plt.title('Customer Groups')
plt.xlabel('PAYMENTS')
plt.ylabel('CREDIT_LIMIT')
plt.show()

# %%
X1=df[['PAYMENTS','CREDIT_LIMIT']].values

# %%
from sklearn.cluster import KMeans
wcss =[]
for i in range(1,8):
    kmean=KMeans(n_clusters=i , init='k-means++',random_state=30)
    kmean.fit(X1)
    wcss.append(kmean.inertia_)

# %%
wcss
# Out:
# [193485384310.1394,
#  103105820031.14664,
#  69158614466.54112,
#  51355245820.4348,
#  38894135705.14193,
#  33718555305.868263,
#  28159434295.644646]

# %%
# plt.plot(range(1,8),wcss
sns.set()
plt.plot(range(1,8), wcss)
plt.title('The Elbow Point Graph')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', random_state=0)

# return a label for each data point based on their cluster
Y1 = kmeans.fit_predict(X1)

print(Y)
# Out:
# [1 0 0 ... 1 1 1]

# %%
from sklearn.metrics import silhouette_score
silhouette_score(X1,Y)
# Out:
# 0.565032260476022

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
pca.fit_transform(X1)
# Out:
# array([[-3786.77718869,   465.29893068],
#        [ 3363.92413643,   760.3753183 ],
#        [ 2018.41784172, -2488.73780601],
#        ...,
#        [-3848.25775772,   361.6266775 ],
#        [-4292.9712446 ,   591.96295312],
#        [-3685.46750606,   244.03782419]])

# %%
from sklearn.metrics import silhouette_score
silhouette_score(X1,Y1)
# Out:
# 0.565032260476022

# %%
# plotting all the clusters and their Centroids

plt.figure(figsize=(8,8))
plt.scatter(X1[Y1==0,0], X1[Y1==0,1], s=50, c='green', label='Cluster 1')
plt.scatter(X1[Y1==1,0], X1[Y1==1,1], s=50, c='red', label='Cluster 2')
plt.scatter(X1[Y1==2,0], X1[Y1==2,1], s=50, c='yellow', label='Cluster 3')
plt.scatter(X1[Y1==3,0], X1[Y1==3,1], s=50, c='violet', label='Cluster 4')
plt.scatter(X1[Y1==4,0], X1[Y1==4,1], s=50, c='blue', label='Cluster 5')

# plot the centroids
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=100, c='cyan', label='Centroids')

plt.title('Customer Groups')
plt.xlabel('CREDIT_LIMIT')
plt.ylabel('PAYMENTS')
plt.show()
